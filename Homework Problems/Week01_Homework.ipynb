# %% [markdown]
# # Week 1 Problem Set
# ## Homework

# %%
# %load_ext nb_mypy
# %nb_mypy On
# Out:
# Running cells with '/opt/homebrew/bin/python3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# **HW0-a**. Reorder the code to check if a string is a palindrome.

# %%
from IPython.display import IFrame
IFrame('https://parsons.problemsolving.io/puzzle/5bd88e89a5cf45ea88b561dec4f7422a', 1000, 400)
# Out:
#         <iframe
#             width="1000"
#             height="400"
#             src="https://parsons.problemsolving.io/puzzle/5bd88e89a5cf45ea88b561dec4f7422a"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# **HW0-b.** Write a function `palindrome(s)`to check if the string `s` is a [Palindrome](https://en.wikipedia.org/wiki/Palindrome). Use iteration for this solution.

# %%
def palindrome(s: str) -> bool:
    n = len(s)
    for idx in range(n//2):
        if s[idx] != s[n-idx-1]:
            return False
    return True

# %%
assert not palindrome("moon") 
assert palindrome("noon") 
assert palindrome("a a") 
assert palindrome("ada") 
assert not palindrome("ad a")

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# **HW-1-a.** Reorder the correct sequence of code to implement bubble sort algorithm version 2. You can check the pseudocode in [Bubble Sort and Insertion Sort](https://data-driven-world.github.io/2023/notes/sorting-algorithms/bubble-sort).
#
# The function should ...
#
# - **modify/mutate** an existing array into a sorted one
# - **return** the number of comparisons made
#
# Hint: To count the number of comparisons made you can simply increment an integer variable (counter) right before the `if` statement.

# %%
from IPython.display import IFrame
IFrame('https://parsons.problemsolving.io/puzzle/5fcbd788fb7d49bba19fea14186c667b', 1000, 400)
# Out:
#         <iframe
#             width="1000"
#             height="400"
#             src="https://parsons.problemsolving.io/puzzle/5fcbd788fb7d49bba19fea14186c667b"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# **HW1-b.** Create a function to implement **Bubble Sort Algorithm version 2**.

# %%
def bubble_sort(array: list[int|float]) -> int:
    count: int = 0
    n = len(array)
    swapped = True
    while swapped:
        swapped = False
        for idx in range(1,n):
            count += 1
            if array[idx-1] > array[idx]:
                array[idx-1], array[idx] = array[idx], array[idx-1]
                swapped = True
    return count

# %%
array: list[int|float] = [10,3,8,47,1,0,-39,8,4,7,6,-5]
count: int = bubble_sort(array)
print(array, count)
assert array == [-39, -5, 0, 1, 3, 4, 6, 7, 8, 8, 10, 47]
assert count == 121
# Out:
# [-39, -5, 0, 1, 3, 4, 6, 7, 8, 8, 10, 47] 121

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# **HW2.** The solution in HW1 can be improved!
#
# The n-th pass places the n-th largest element into its final place (i.e. after 1 cycle, the (1st) largest element will be in its correct position).
#
# Hence, we can reduce subsequent iterations by only considering the other (unsorted) `n-1` elements in the array.
#
# Implement the algorithm of **Bubble Sort version 4** under [Bubble Sort and Insertion Sort](https://data-driven-world.github.io/2023/notes/sorting-algorithms/bubble-sort).

# %%
def bubble_sort(array: list[int|float]) -> int:
    count: int = 0
    n = len(array)
    swapped = True
    while swapped:
        swapped = False
        for idx in range(1,n):
            count += 1
            if array[idx-1] > array[idx]:
                array[idx-1], array[idx] = array[idx], array[idx-1]
                swapped = True
        n -= 1
    return count

# %%
array: list[int|float] = [10,3,8,47,1,0,-39,8,4,7,6,-5]
count: int = bubble_sort(array)
print(array, count)
assert array == [-39, -5, 0, 1, 3, 4, 6, 7, 8, 8, 10, 47]
assert count == 66
# Out:
# [-39, -5, 0, 1, 3, 4, 6, 7, 8, 8, 10, 47] 66

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %%
from Crypto.Cipher import AES
from Crypto.Util.Padding import unpad

def decrypt_aes_ecb(encrypted_data, key):
    """
    Decrypts AES-encrypted data using ECB mode and the given key.

    :param encrypted_data: The encrypted data as bytes
    :param key: The key as bytes, should be either 16, 24, or 32 bytes long
    :return: The decrypted plaintext as a string, assuming the plaintext was UTF-8 encoded
    """
    # Create a new AES cipher object in ECB mode
    cipher = AES.new(key, AES.MODE_ECB)

    # Decrypt the data
    decrypted_data = cipher.decrypt(encrypted_data)

    # Remove padding if the original plaintext was padded to the AES block size
    try:
        decrypted_data = unpad(decrypted_data, AES.block_size)
    except ValueError:
        # Handle padding errors if padding was incorrect or not present
        pass

    return decrypted_data.decode('utf-8')

# Example usage
if __name__ == "__main__":
    # You need to provide these values
    encrypted_message = b'\x76\x80\x92\x3E\xF4\xF4\x35\x0F\x90\xFA\x11\x12\xCE\xB9\x7C\xFB'  # Example: this should be your actual encrypted data
    key = b'\xE6\x34\xA2\x6A\xD4\x6F\x1B\xE0\xB8\xA0\x4E\x00\xBE\x72\x25\x19'  # Example key; must be exactly 16, 24, or 32 bytes long for AES

    # Decrypt the message
    try:
        decrypted_message = decrypt_aes_ecb(encrypted_message, key)
        print("Decrypted Message:", decrypted_message)
    except Exception as e:
        print("An error occurred during decryption:", str(e))
# Out:
# Running cells with '/opt/homebrew/bin/python3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
